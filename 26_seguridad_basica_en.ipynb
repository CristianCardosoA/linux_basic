# %% [markdown]
# # Basic security.
#
# * *Hardening*. It consists of configuring the services of a system to avoid vulnerabildiadeds.
# * *Firewall*. Allows GNU/Linux to filter access to the networks with which it communicates.
# * *File integration*. Allows you to verify that local system files have not been compromised.

# %% [markdown]
# ## File integrity.
# ### _SELinux_.
# http://selinuxproject.org/page/Main_Page
# #### enforcing
# #### permissive
# #### disabled
# #### The _/etc/selinux/config_ file
#
# ### _AppArmor_.
# http://wiki.apparmor.net/index.php/Main_Page
# #### _enforced_
# #### _complain_
# #### The directory _/etc/apparmor.d/_

# %%
cat  /etc/selinux/config

# %% [markdown]
# ## Firewalls.
# ### _iptables_.
# #### The _/etc/sysconfig/iptables_ file

# %%
sudo iptables -S

# %% [markdown]
# ### _firewalld_.
# #### The file _ /etc/firewalld_

# %%
systemctl status firewalld

# %%
sudo cat /etc/firewalld/zones/public.xml

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Creative Commons License" style=" border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />This work is licensed under a <a rel="license " href="http://creativecommons.org/licenses/by/4.0/">Creative Commons Attribution 4.0 International License</a>.</p>
# <p style="text-align: center">Content created by: José Luis Chiquete Valdivieso. 2019.</p><p style="text-align: center">Content modified by: Cristian Cardoso Arellano. 2023.</p>
