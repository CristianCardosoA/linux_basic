# %% [markdown]
# # *GNU/Linux* directory hierarchy.
#
# *UNIX* and *GNU/Linux* systems have a standardized directory structure, which has been proposed by the *Linux Foundation*.
#
# This specification is known as the standard file system hierarchy ([*fhs*](https://wiki.linuxfoundation.org/lsb/fhs)).
#
# The current specification can be consulted from:

# %% [markdown]
# https://refspecs.linuxfoundation.org/FHS_3.0/fhs/index.html

# %% [markdown]
# ### The root directory ```/```.
#
# This is the home directory of a *UNIX* or *GNU/Linux* system. It is used as the reference to the rest of the system.

# %%
tree / -L 1
# Out:
# /
# ├── bin -> usr/bin
# ├── boot
# ├── dev
# ├── etc
# ├── home
# ├── initrd.img -> boot/initrd.img-5.10.0-16-amd64
# ├── initrd.img.old -> boot/initrd.img-5.10.0-16-amd64
# ├── lib -> usr/lib
# ├── lib32 -> usr/lib32
# ├── lib64 -> usr/lib64
# ├── libx32 -> usr/libx32
# ├── lost+found
# ├── media
# ├── mnt
# ├── opt
# ├── proc
# ├── root
# ├── run
# ├── sbin -> usr/sbin
# ├── srv
# ├── sys
# ├── tmp
# ├── usr
# ├── var
# ├── vmlinuz -> boot/vmlinuz-5.10.0-16-amd64
# └── vmlinuz.old -> boot/vmlinuz-5.10.0-16-amd64
#
# 22 directories, 4 files

# %% [markdown]
# ### The ```/home/``` directory.
#
# This is the directory where the *home* of each user on the system is located.

# %%
tree /home -L 1
# Out:
# /home
# └── oi
#
# 1 directory, 0 files

# %% [markdown]
# ### The ```/bin/``` directory.
#
# It is the directory where the main system commands are located.

# %%
tree /bin -L 1
# Out:
# /bin
# ├── [
# ├── aa-enabled
# ├── aa-exec
# ├── ab
# ├── addpart
# ├── addr2line -> x86_64-linux-gnu-addr2line
# ├── apropos -> whatis
# ├── apt
# ├── apt-cache
# ├── apt-cdrom
# ├── apt-config
# ├── apt-extracttemplates
# ├── apt-ftparchive
# ├── apt-get
# ├── apt-key
# ├── apt-listchanges
# ├── apt-mark
# ├── apt-sortpkgs
# ├── ar -> x86_64-linux-gnu-ar
# ├── arch
# ├── aria_chk
# ├── aria_dump_log
# ├── aria_ftdump
# ├── aria_pack
# ├── aria_read_log
# ├── as -> x86_64-linux-gnu-as
# ├── awk -> /etc/alternatives/awk
# ├── b2sum
# ├── base32
# ├── base64
# ├── basename
# ├── basenc
# ├── bash
# ├── bashbug
# ├── bccmd
# ├── bluemoon
# ├── bluetoothctl
# ├── bootctl
# ├── btattach
# ├── btmgmt
# ├── btmon
# ├── buildhash
# ├── bunzip2
# ├── busctl
# ├── busybox
# ├── bzcat
# ├── bzcmp -> bzdiff
# ├── bzdiff
# ├── bzegrep -> bzgrep
# ├── bzexe
# ├── bzfgrep -> bzgrep
# ├── bzgrep
# ├── bzip2
# ├── bzip2recover
# ├── bzless -> bzmore
# ├── bzmore
# ├── c++ -> /etc/alternatives/c++
# ├── c89 -> /etc/alternatives/c89
# ├── c89-gcc
# ├── c99 -> /etc/alternatives/c99
# ├── c99-gcc
# ├── captoinfo -> tic
# ├── cat
# ├── catchsegv
# ├── catman
# ├── cc -> /etc/alternatives/cc
# ├── c++filt -> x86_64-linux-gnu-c++filt
# ├── cgi-fcgi
# ├── chage
# ├── chardet -> chardetect
# ├── chardetect
# ├── chattr
# ├── chcon
# ├── checkgid
# ├── chfn
# ├── chgrp
# ├── chmod
# ├── choom
# ├── chown
# ├── chrt
# ├── chsh
# ├── chvt
# ├── ciptool
# ├── ckbcomp
# ├── cksum
# ├── clear
# ├── clear_console
# ├── cmp
# ├── codepage
# ├── col
# ├── colcrt
# ├── colrm
# ├── column
# ├── comm
# ├── compose -> run-mailcap
# ├── corelist
# ├── cp
# ├── cpan
# ├── cpan5.32-x86_64-linux-gnu
# ├── cpio
# ├── cpp -> cpp-10
# ├── cpp-10 -> x86_64-linux-gnu-cpp-10
# ├── c_rehash
# ├── crontab
# ├── csplit
# ├── ctstat -> lnstat
# ├── curl
# ├── cut
# ├── cvtsudoers
# ├── dash
# ├── date
# ├── dbilogstrip
# ├── dbiprof
# ├── dbiproxy
# ├── dbus-cleanup-sockets
# ├── dbus-daemon
# ├── dbus-monitor
# ├── dbus-run-session
# ├── dbus-send
# ├── dbus-update-activation-environment
# ├── dbus-uuidgen
# ├── dd
# ├── deallocvt
# ├── debconf
# ├── debconf-apt-progress
# ├── debconf-communicate
# ├── debconf-copydb
# ├── debconf-escape
# ├── debconf-set-selections
# ├── debconf-show
# ├── debianbts
# ├── deb-systemd-helper
# ├── deb-systemd-invoke
# ├── defmt-c
# ├── defmt-sh
# ├── delpart
# ├── delv
# ├── df
# ├── dh_bash-completion
# ├── dh_perl_dbi
# ├── diff
# ├── diff3
# ├── dig
# ├── dir
# ├── dircolors
# ├── dirmngr
# ├── dirmngr-client
# ├── dirname
# ├── discover-config
# ├── dmesg
# ├── dnsdomainname -> hostname
# ├── dnstap-read
# ├── domainname -> hostname
# ├── dotlockfile
# ├── dpkg
# ├── dpkg-architecture
# ├── dpkg-buildflags
# ├── dpkg-buildpackage
# ├── dpkg-checkbuilddeps
# ├── dpkg-deb
# ├── dpkg-distaddfile
# ├── dpkg-divert
# ├── dpkg-genbuildinfo
# ├── dpkg-genchanges
# ├── dpkg-gencontrol
# ├── dpkg-gensymbols
# ├── dpkg-maintscript-helper
# ├── dpkg-mergechangelogs
# ├── dpkg-name
# ├── dpkg-parsechangelog
# ├── dpkg-query
# ├── dpkg-realpath
# ├── dpkg-scanpackages
# ├── dpkg-scansources
# ├── dpkg-shlibdeps
# ├── dpkg-source
# ├── dpkg-split
# ├── dpkg-statoverride
# ├── dpkg-trigger
# ├── dpkg-vendor
# ├── du
# ├── dumpkeys
# ├── dwp -> x86_64-linux-gnu-dwp
# ├── echo
# ├── edit -> run-mailcap
# ├── editor -> /etc/alternatives/editor
# ├── egrep
# ├── eject
# ├── elfedit -> x86_64-linux-gnu-elfedit
# ├── enc2xs
# ├── encguess
# ├── env
# ├── envsubst
# ├── eqn
# ├── ex -> /etc/alternatives/ex
# ├── expand
# ├── expiry
# ├── expr
# ├── factor
# ├── faillog
# ├── faked-sysv
# ├── faked-tcp
# ├── fakeroot -> /etc/alternatives/fakeroot
# ├── fakeroot-sysv
# ├── fakeroot-tcp
# ├── fallocate
# ├── false
# ├── fcgistarter
# ├── fgconsole
# ├── fgrep
# ├── filan
# ├── file
# ├── fincore
# ├── find
# ├── findaffix
# ├── findmnt
# ├── flock
# ├── fmt
# ├── fold
# ├── free
# ├── funzip
# ├── fuser
# ├── g++ -> g++-10
# ├── g++-10 -> x86_64-linux-gnu-g++-10
# ├── galera_new_cluster
# ├── galera_recovery
# ├── gatttool
# ├── gawk
# ├── gcc -> gcc-10
# ├── gcc-10 -> x86_64-linux-gnu-gcc-10
# ├── gcc-ar -> gcc-ar-10
# ├── gcc-ar-10 -> x86_64-linux-gnu-gcc-ar-10
# ├── gcc-nm -> gcc-nm-10
# ├── gcc-nm-10 -> x86_64-linux-gnu-gcc-nm-10
# ├── gcc-ranlib -> gcc-ranlib-10
# ├── gcc-ranlib-10 -> x86_64-linux-gnu-gcc-ranlib-10
# ├── gcov -> gcov-10
# ├── gcov-10 -> x86_64-linux-gnu-gcov-10
# ├── gcov-dump -> gcov-dump-10
# ├── gcov-dump-10 -> x86_64-linux-gnu-gcov-dump-10
# ├── gcov-tool -> gcov-tool-10
# ├── gcov-tool-10 -> x86_64-linux-gnu-gcov-tool-10
# ├── gencat
# ├── geqn -> eqn
# ├── getconf
# ├── getent
# ├── getkeycodes
# ├── getopt
# ├── gettext
# ├── gettext.sh
# ├── git
# ├── git-receive-pack -> git
# ├── git-shell
# ├── git-upload-archive -> git
# ├── git-upload-pack -> git
# ├── gmake -> make
# ├── gold -> x86_64-linux-gnu-gold
# ├── gpasswd
# ├── gpg
# ├── gpg-agent
# ├── gpgcompose
# ├── gpgconf
# ├── gpg-connect-agent
# ├── gpgparsemail
# ├── gpgsm
# ├── gpgsplit
# ├── gpgtar
# ├── gpgv
# ├── gpg-wks-server
# ├── gpg-zip
# ├── gpic -> pic
# ├── gprof -> x86_64-linux-gnu-gprof
# ├── grep
# ├── groff
# ├── grog
# ├── grops
# ├── grotty
# ├── groups
# ├── grub-editenv
# ├── grub-file
# ├── grub-fstest
# ├── grub-glue-efi
# ├── grub-kbdcomp
# ├── grub-menulst2cfg
# ├── grub-mkfont
# ├── grub-mkimage
# ├── grub-mklayout
# ├── grub-mknetdir
# ├── grub-mkpasswd-pbkdf2
# ├── grub-mkrelpath
# ├── grub-mkrescue
# ├── grub-mkstandalone
# ├── grub-mount
# ├── grub-ntldr-img -> ../lib/grub/i386-pc/grub-ntldr-img
# ├── grub-render-label
# ├── grub-script-check
# ├── grub-syslinux2cfg
# ├── gtbl -> tbl
# ├── gunzip
# ├── gzexe
# ├── gzip
# ├── h2ph
# ├── h2xs
# ├── hciattach
# ├── hciconfig
# ├── hcitool
# ├── hd -> hexdump
# ├── head
# ├── helpztags
# ├── hex2hcd
# ├── hexdump
# ├── host
# ├── hostid
# ├── hostname
# ├── hostnamectl
# ├── htcacheclean
# ├── htdbm
# ├── htdigest
# ├── htpasswd
# ├── i386 -> setarch
# ├── icombine
# ├── iconv
# ├── id
# ├── ijoin
# ├── infocmp
# ├── infotocap -> tic
# ├── innochecksum
# ├── innotop
# ├── install
# ├── instmodsh
# ├── ionice
# ├── ip
# ├── ipcmk
# ├── ipcrm
# ├── ipcs
# ├── ischroot
# ├── ispell
# ├── ispell-wrapper
# ├── join
# ├── journalctl
# ├── json_pp
# ├── kbdinfo
# ├── kbd_mode
# ├── kbxutil
# ├── kernel-install
# ├── kill
# ├── killall
# ├── kmod
# ├── l2ping
# ├── l2test
# ├── laptop-detect
# ├── last
# ├── lastb -> last
# ├── lastlog
# ├── lcf
# ├── ld -> x86_64-linux-gnu-ld
# ├── ld.bfd -> x86_64-linux-gnu-ld.bfd
# ├── ldd
# ├── ld.gold -> x86_64-linux-gnu-ld.gold
# ├── less
# ├── lessecho
# ├── lessfile -> lesspipe
# ├── lesskey
# ├── lesspipe
# ├── lexgrog
# ├── lft -> /etc/alternatives/lft
# ├── lft.db
# ├── libnetcfg
# ├── link
# ├── linux32 -> setarch
# ├── linux64 -> setarch
# ├── linux-boot-prober
# ├── linux-check-removal
# ├── linux-update-symlinks
# ├── linux-version
# ├── ln
# ├── lnstat
# ├── loadkeys
# ├── loadunimap
# ├── locale
# ├── localectl
# ├── localedef
# ├── logger
# ├── login
# ├── loginctl
# ├── logname
# ├── logresolve
# ├── look
# ├── ls
# ├── lsattr
# ├── lsblk
# ├── lsb_release
# ├── lscpu
# ├── lsinitramfs
# ├── lsipc
# ├── lslocks
# ├── lslogins
# ├── lsmem
# ├── lsmod -> kmod
# ├── lsns
# ├── lsof
# ├── lspci
# ├── lspgpot
# ├── lsusb
# ├── lto-dump-10 -> x86_64-linux-gnu-lto-dump-10
# ├── lzcat -> /etc/alternatives/lzcat
# ├── lzcmp -> /etc/alternatives/lzcmp
# ├── lzdiff -> /etc/alternatives/lzdiff
# ├── lzegrep -> /etc/alternatives/lzegrep
# ├── lzfgrep -> /etc/alternatives/lzfgrep
# ├── lzgrep -> /etc/alternatives/lzgrep
# ├── lzless -> /etc/alternatives/lzless
# ├── lzma -> /etc/alternatives/lzma
# ├── lzmainfo
# ├── lzmore -> /etc/alternatives/lzmore
# ├── make
# ├── make-first-existing-target
# ├── man
# ├── mandb
# ├── manpath
# ├── man-recode
# ├── mapscrn
# ├── mariadb
# ├── mariadb-access
# ├── mariadb-admin
# ├── mariadb-analyze -> mariadb-check
# ├── mariadb-binlog
# ├── mariadb-check
# ├── mariadbcheck -> mariadb-check
# ├── mariadb-conv
# ├── mariadb-convert-table-format
# ├── mariadbd-multi
# ├── mariadbd-safe
# ├── mariadbd-safe-helper
# ├── mariadb-dump
# ├── mariadb-dumpslow
# ├── mariadb-find-rows
# ├── mariadb-fix-extensions
# ├── mariadb-hotcopy
# ├── mariadb-import
# ├── mariadb-install-db
# ├── mariadb-optimize -> mariadb-check
# ├── mariadb-plugin
# ├── mariadb-repair -> mariadb-check
# ├── mariadb-report
# ├── mariadb-secure-installation
# ├── mariadb-service-convert
# ├── mariadb-setpermission
# ├── mariadb-show
# ├── mariadb-slap
# ├── mariadb-tzinfo-to-sql
# ├── mariadb-upgrade
# ├── mariadb-waitpid
# ├── mawk
# ├── mc
# ├── mcdiff -> mc
# ├── mcedit -> mc
# ├── mcookie
# ├── mcview -> mc
# ├── md5sum
# ├── md5sum.textutils -> md5sum
# ├── mdig
# ├── memusage
# ├── memusagestat
# ├── mesg
# ├── migrate-pubring-from-classic-gpg
# ├── mkdir
# ├── mkfifo
# ├── mk_modmap
# ├── mknod
# ├── mktemp
# ├── more
# ├── mount
# ├── mountpoint
# ├── mpris-proxy
# ├── msql2mysql
# ├── mt -> /etc/alternatives/mt
# ├── mt-gnu
# ├── mtrace
# ├── munchlist
# ├── mv
# ├── myisamchk
# ├── myisam_ftdump
# ├── myisamlog
# ├── myisampack
# ├── my_print_defaults
# ├── mysql -> mariadb
# ├── mysqlaccess -> mariadb-access
# ├── mysqladmin -> mariadb-admin
# ├── mysqlanalyze -> mariadb-check
# ├── mysqlbinlog -> mariadb-binlog
# ├── mysqlcheck -> mariadb-check
# ├── mysql_convert_table_format -> mariadb-convert-table-format
# ├── mysqld_multi -> mariadbd-multi
# ├── mysqld_safe -> mariadbd-safe
# ├── mysqld_safe_helper -> mariadbd-safe-helper
# ├── mysqldump -> mariadb-dump
# ├── mysqldumpslow -> mariadb-dumpslow
# ├── mysql_find_rows -> mariadb-find-rows
# ├── mysql_fix_extensions -> mariadb-fix-extensions
# ├── mysqlhotcopy -> mariadb-hotcopy
# ├── mysqlimport -> mariadb-import
# ├── mysql_install_db -> mariadb-install-db
# ├── mysqloptimize -> mariadb-check
# ├── mysql_plugin -> mariadb-plugin
# ├── mysqlrepair -> mariadb-check
# ├── mysqlreport -> mariadb-report
# ├── mysql_secure_installation -> mariadb-secure-installation
# ├── mysql_setpermission -> mariadb-setpermission
# ├── mysqlshow -> mariadb-show
# ├── mysqlslap -> mariadb-slap
# ├── mysql_tzinfo_to_sql -> mariadb-tzinfo-to-sql
# ├── mysql_upgrade -> mariadb-upgrade
# ├── mysql_waitpid -> mariadb-waitpid
# ├── mytop
# ├── namei
# ├── nano
# ├── nawk -> /etc/alternatives/nawk
# ├── nc -> /etc/alternatives/nc
# ├── nc.traditional
# ├── neqn
# ├── netcat -> /etc/alternatives/netcat
# ├── networkctl
# ├── newgrp
# ├── ngettext
# ├── nice
# ├── nisdomainname -> hostname
# ├── nl
# ├── nm -> x86_64-linux-gnu-nm
# ├── nohup
# ├── nproc
# ├── nroff
# ├── nsenter
# ├── nslookup
# ├── nstat
# ├── nsupdate
# ├── numfmt
# ├── obexctl
# ├── objcopy -> x86_64-linux-gnu-objcopy
# ├── objdump -> x86_64-linux-gnu-objdump
# ├── od
# ├── open -> /etc/alternatives/open
# ├── openssl
# ├── openvt
# ├── os-prober
# ├── pager -> /etc/alternatives/pager
# ├── partx
# ├── passwd
# ├── paste
# ├── patch
# ├── pathchk
# ├── pdb3 -> pdb3.9
# ├── pdb3.9 -> ../lib/python3.9/pdb.py
# ├── peekfd
# ├── perf
# ├── perl
# ├── perl5.32.1
# ├── perl5.32-x86_64-linux-gnu
# ├── perlbug
# ├── perldoc
# ├── perlivp
# ├── perlthanks
# ├── perror
# ├── pgrep
# ├── phar -> /etc/alternatives/phar
# ├── phar7.4 -> phar7.4.phar
# ├── phar7.4.phar
# ├── phar.phar -> /etc/alternatives/phar.phar
# ├── phar.phar7.4 -> phar7.4.phar
# ├── php -> /etc/alternatives/php
# ├── php7.4
# ├── pic
# ├── pico -> /etc/alternatives/pico
# ├── piconv
# ├── pidof -> /sbin/killall5
# ├── pidwait
# ├── pinentry -> /etc/alternatives/pinentry
# ├── pinentry-curses
# ├── ping
# ├── ping4 -> ping
# ├── ping6 -> ping
# ├── pinky
# ├── pkill -> pgrep
# ├── pl2pm
# ├── pldd
# ├── pmap
# ├── pod2html
# ├── pod2man
# ├── pod2text
# ├── pod2usage
# ├── podchecker
# ├── pr
# ├── preconv
# ├── print -> run-mailcap
# ├── printenv
# ├── printf
# ├── prlimit
# ├── procan
# ├── prove
# ├── prtstat
# ├── ps
# ├── psfaddtable -> psfxtable
# ├── psfgettable -> psfxtable
# ├── psfstriptable -> psfxtable
# ├── psfxtable
# ├── pslog
# ├── pstree
# ├── pstree.x11 -> pstree
# ├── ptar
# ├── ptardiff
# ├── ptargrep
# ├── ptx
# ├── pwd
# ├── pwdx
# ├── py3clean
# ├── py3compile
# ├── py3versions -> ../share/python3/py3versions.py
# ├── pydoc3 -> pydoc3.9
# ├── pydoc3.9
# ├── pygettext3 -> pygettext3.9
# ├── pygettext3.9
# ├── python3 -> python3.9
# ├── python3.9
# ├── querybts
# ├── ranlib -> x86_64-linux-gnu-ranlib
# ├── rbash -> bash
# ├── rcp -> /etc/alternatives/rcp
# ├── rctest
# ├── rdma
# ├── readelf -> x86_64-linux-gnu-readelf
# ├── readlink
# ├── realpath
# ├── renice
# ├── replace
# ├── reportbug
# ├── report-hw
# ├── reset -> tset
# ├── resizecons
# ├── resizepart
# ├── resolvectl
# ├── resolveip
# ├── resolve_stack_dump
# ├── rev
# ├── rfcomm
# ├── rgrep
# ├── rlogin -> /etc/alternatives/rlogin
# ├── rm
# ├── rmdir
# ├── rnano -> nano
# ├── rotatelogs
# ├── routef
# ├── routel
# ├── rpcgen
# ├── rrsync -> ../share/rsync/scripts/rrsync
# ├── rsh -> /etc/alternatives/rsh
# ├── rsync
# ├── rsync-ssl
# ├── rtstat -> lnstat
# ├── runcon
# ├── run-mailcap
# ├── run-parts
# ├── rview -> /etc/alternatives/rview
# ├── rvim -> /etc/alternatives/rvim
# ├── savelog
# ├── scp
# ├── screendump
# ├── script
# ├── scriptlive
# ├── scriptreplay
# ├── sdiff
# ├── sdptool
# ├── sed
# ├── see -> run-mailcap
# ├── select-default-iwrap
# ├── select-editor
# ├── sensible-browser
# ├── sensible-editor
# ├── sensible-pager
# ├── seq
# ├── setarch
# ├── setfont
# ├── setkeycodes
# ├── setleds
# ├── setlogcons
# ├── setmetamode
# ├── setpci
# ├── setpriv
# ├── setsid
# ├── setterm
# ├── setupcon
# ├── setvtrgb
# ├── sftp
# ├── sg -> newgrp
# ├── sh -> dash
# ├── sha1sum
# ├── sha224sum
# ├── sha256sum
# ├── sha384sum
# ├── sha512sum
# ├── shasum
# ├── showconsolefont
# ├── showkey
# ├── shred
# ├── shuf
# ├── size -> x86_64-linux-gnu-size
# ├── skill
# ├── slabtop
# ├── sleep
# ├── slogin -> ssh
# ├── snice -> skill
# ├── socat
# ├── soelim
# ├── sort
# ├── sotruss
# ├── splain
# ├── split
# ├── splitfont
# ├── sprof
# ├── ss
# ├── ssh
# ├── ssh-add
# ├── ssh-agent
# ├── ssh-argv0
# ├── ssh-copy-id
# ├── ssh-keygen
# ├── ssh-keyscan
# ├── stat
# ├── stdbuf
# ├── streamzip
# ├── strings -> x86_64-linux-gnu-strings
# ├── strip -> x86_64-linux-gnu-strip
# ├── stty
# ├── su
# ├── sudo
# ├── sudoedit -> sudo
# ├── sudoreplay
# ├── sum
# ├── sync
# ├── systemctl
# ├── systemd -> /lib/systemd/systemd
# ├── systemd-analyze
# ├── systemd-ask-password
# ├── systemd-cat
# ├── systemd-cgls
# ├── systemd-cgtop
# ├── systemd-delta
# ├── systemd-detect-virt
# ├── systemd-escape
# ├── systemd-hwdb
# ├── systemd-id128
# ├── systemd-inhibit
# ├── systemd-machine-id-setup
# ├── systemd-mount
# ├── systemd-notify
# ├── systemd-path
# ├── systemd-resolve -> resolvectl
# ├── systemd-run
# ├── systemd-socket-activate
# ├── systemd-stdio-bridge
# ├── systemd-sysusers
# ├── systemd-tmpfiles
# ├── systemd-tty-ask-password-agent
# ├── systemd-umount -> systemd-mount
# ├── tabs
# ├── tac
# ├── tail
# ├── tar
# ├── tasksel
# ├── taskset
# ├── tbl
# ├── tee
# ├── telnet -> /etc/alternatives/telnet
# ├── telnet.netkit
# ├── tempfile
# ├── test
# ├── tic
# ├── timedatectl
# ├── timeout
# ├── tload
# ├── toe
# ├── top
# ├── touch
# ├── tput
# ├── tr
# ├── traceproto -> /etc/alternatives/traceproto
# ├── traceproto.db
# ├── traceroute -> /etc/alternatives/traceroute
# ├── traceroute6 -> /etc/alternatives/traceroute6
# ├── traceroute6.db -> traceroute.db
# ├── traceroute.db
# ├── traceroute-nanog
# ├── tree
# ├── troff
# ├── true
# ├── truncate
# ├── tryaffix
# ├── tset
# ├── tsort
# ├── tty
# ├── tzselect
# ├── ucf
# ├── ucfq
# ├── ucfr
# ├── udevadm
# ├── ul
# ├── umount
# ├── uname
# ├── uncompress
# ├── unexpand
# ├── unicode_start
# ├── unicode_stop
# ├── uniq
# ├── unlink
# ├── unlzma -> /etc/alternatives/unlzma
# ├── unmkinitramfs
# ├── unshare
# ├── unxz -> xz
# ├── unzip
# ├── unzipsfx
# ├── update-alternatives
# ├── update-mime-database
# ├── uptime
# ├── usb-devices
# ├── usbhid-dump
# ├── usbreset
# ├── users
# ├── utmpdump
# ├── vdir
# ├── vi -> /etc/alternatives/vi
# ├── view -> /etc/alternatives/view
# ├── vim -> /etc/alternatives/vim
# ├── vim.basic
# ├── vimdiff -> /etc/alternatives/vimdiff
# ├── vim.tiny
# ├── vimtutor
# ├── vmstat
# ├── w
# ├── w3m
# ├── w3mman
# ├── wall
# ├── watch
# ├── watchgnupg
# ├── wc
# ├── wdctl
# ├── wget
# ├── whatis
# ├── whereis
# ├── which
# ├── whiptail
# ├── who
# ├── whoami
# ├── wpa_passphrase
# ├── write -> /etc/alternatives/write
# ├── write.ul
# ├── wsrep_sst_common
# ├── wsrep_sst_mariabackup
# ├── wsrep_sst_mysqldump
# ├── wsrep_sst_rsync
# ├── wsrep_sst_rsync_wan -> wsrep_sst_rsync
# ├── www-browser -> /etc/alternatives/www-browser
# ├── x86_64 -> setarch
# ├── x86_64-linux-gnu-addr2line
# ├── x86_64-linux-gnu-ar
# ├── x86_64-linux-gnu-as
# ├── x86_64-linux-gnu-c++filt
# ├── x86_64-linux-gnu-cpp -> cpp-10
# ├── x86_64-linux-gnu-cpp-10
# ├── x86_64-linux-gnu-dwp
# ├── x86_64-linux-gnu-elfedit
# ├── x86_64-linux-gnu-g++ -> g++-10
# ├── x86_64-linux-gnu-g++-10
# ├── x86_64-linux-gnu-gcc -> gcc-10
# ├── x86_64-linux-gnu-gcc-10
# ├── x86_64-linux-gnu-gcc-ar -> gcc-ar-10
# ├── x86_64-linux-gnu-gcc-ar-10
# ├── x86_64-linux-gnu-gcc-nm -> gcc-nm-10
# ├── x86_64-linux-gnu-gcc-nm-10
# ├── x86_64-linux-gnu-gcc-ranlib -> gcc-ranlib-10
# ├── x86_64-linux-gnu-gcc-ranlib-10
# ├── x86_64-linux-gnu-gcov -> gcov-10
# ├── x86_64-linux-gnu-gcov-10
# ├── x86_64-linux-gnu-gcov-dump -> gcov-dump-10
# ├── x86_64-linux-gnu-gcov-dump-10
# ├── x86_64-linux-gnu-gcov-tool -> gcov-tool-10
# ├── x86_64-linux-gnu-gcov-tool-10
# ├── x86_64-linux-gnu-gold -> x86_64-linux-gnu-ld.gold
# ├── x86_64-linux-gnu-gprof
# ├── x86_64-linux-gnu-ld -> x86_64-linux-gnu-ld.bfd
# ├── x86_64-linux-gnu-ld.bfd
# ├── x86_64-linux-gnu-ld.gold
# ├── x86_64-linux-gnu-lto-dump-10
# ├── x86_64-linux-gnu-nm
# ├── x86_64-linux-gnu-objcopy
# ├── x86_64-linux-gnu-objdump
# ├── x86_64-linux-gnu-ranlib
# ├── x86_64-linux-gnu-readelf
# ├── x86_64-linux-gnu-size
# ├── x86_64-linux-gnu-strings
# ├── x86_64-linux-gnu-strip
# ├── xargs
# ├── xauth
# ├── xdg-user-dir
# ├── xdg-user-dirs-update
# ├── xsubpp
# ├── xxd
# ├── xz
# ├── xzcat -> xz
# ├── xzcmp -> xzdiff
# ├── xzdiff
# ├── xzegrep -> xzgrep
# ├── xzfgrep -> xzgrep
# ├── xzgrep
# ├── xzless
# ├── xzmore
# ├── yes
# ├── ypdomainname -> hostname
# ├── zcat
# ├── zcmp
# ├── zdiff
# ├── zdump
# ├── zegrep
# ├── zfgrep
# ├── zforce
# ├── zgrep
# ├── zip
# ├── zipcloak
# ├── zipdetails
# ├── zipgrep
# ├── zipinfo
# ├── zipnote
# ├── zipsplit
# ├── zless
# ├── zmore
# └── znew
#
# 0 directories, 934 files

# %% [markdown]
# ### ### The ```/sbin/``` directory.
#
# It is the directory of "safe" applications.

# %%
tree /sbin -L 1
# Out:
# /sbin
# ├── a2disconf -> a2enmod
# ├── a2dismod -> a2enmod
# ├── a2dissite -> a2enmod
# ├── a2enconf -> a2enmod
# ├── a2enmod
# ├── a2ensite -> a2enmod
# ├── a2query
# ├── aa-remove-unknown
# ├── aa-status
# ├── aa-teardown
# ├── accessdb
# ├── addgnupghome
# ├── addgroup -> adduser
# ├── add-shell
# ├── adduser
# ├── agetty
# ├── anacron
# ├── apache2
# ├── apache2ctl
# ├── apachectl -> apache2ctl
# ├── apparmor_parser
# ├── apparmor_status -> aa-status
# ├── applygnupgdefaults
# ├── arpd
# ├── aspell-autobuildhash
# ├── avahi-autoipd
# ├── badblocks
# ├── biosdecode
# ├── blkdeactivate
# ├── blkdiscard
# ├── blkid
# ├── blkzone
# ├── blockdev
# ├── bluetoothd -> ../libexec/bluetooth/bluetoothd
# ├── bridge
# ├── capsh
# ├── cfdisk
# ├── chcpu
# ├── check_forensic
# ├── chgpasswd
# ├── chmem
# ├── chpasswd
# ├── chroot
# ├── cpgr -> cppw
# ├── cppw
# ├── cron
# ├── ctrlaltdel
# ├── debugfs
# ├── delgroup -> deluser
# ├── deluser
# ├── depmod -> /bin/kmod
# ├── devlink
# ├── dhclient
# ├── dhclient-script
# ├── discover
# ├── discover-modprobe
# ├── discover-pkginstall
# ├── dmeventd
# ├── dmidecode
# ├── dmsetup
# ├── dmstats -> dmsetup
# ├── dpkg-fsys-usrunmess
# ├── dpkg-preconfigure
# ├── dpkg-reconfigure
# ├── dumpe2fs
# ├── e2freefrag
# ├── e2fsck
# ├── e2image
# ├── e2label -> tune2fs
# ├── e2mmpstatus -> dumpe2fs
# ├── e2scrub
# ├── e2scrub_all
# ├── e2undo
# ├── e4crypt
# ├── e4defrag
# ├── faillock
# ├── fdformat
# ├── fdisk
# ├── filefrag
# ├── findfs
# ├── fsadm
# ├── fsck
# ├── fsck.cramfs
# ├── fsck.ext2 -> e2fsck
# ├── fsck.ext3 -> e2fsck
# ├── fsck.ext4 -> e2fsck
# ├── fsck.minix
# ├── fsfreeze
# ├── fstab-decode
# ├── fstrim
# ├── genl
# ├── getcap
# ├── getpcaps
# ├── getty -> agetty
# ├── groupadd
# ├── groupdel
# ├── groupmems
# ├── groupmod
# ├── grpck
# ├── grpconv
# ├── grpunconv
# ├── grub-bios-setup -> ../lib/grub/i386-pc/grub-bios-setup
# ├── grub-install
# ├── grub-macbless
# ├── grub-mkconfig
# ├── grub-mkdevicemap
# ├── grub-probe
# ├── grub-reboot
# ├── grub-set-default
# ├── halt -> /bin/systemctl
# ├── httxt2dbm
# ├── hwclock
# ├── iconvconfig
# ├── ifdown -> ifup
# ├── ifquery -> ifup
# ├── ifup
# ├── init -> /lib/systemd/systemd
# ├── insmod -> /bin/kmod
# ├── installkernel
# ├── invoke-rc.d
# ├── ip -> /bin/ip
# ├── isosize
# ├── ispell-autobuildhash
# ├── iw
# ├── iwconfig
# ├── iwevent
# ├── iwgetid
# ├── iwlist
# ├── iwpriv
# ├── iwspy
# ├── kbdrate
# ├── killall5
# ├── ldattach
# ├── ldconfig
# ├── locale-gen
# ├── logrotate
# ├── logsave
# ├── losetup
# ├── lsmod -> /bin/kmod
# ├── lvchange -> lvm
# ├── lvconvert -> lvm
# ├── lvcreate -> lvm
# ├── lvdisplay -> lvm
# ├── lvextend -> lvm
# ├── lvm
# ├── lvmconfig -> lvm
# ├── lvmdiskscan -> lvm
# ├── lvmdump
# ├── lvmpolld
# ├── lvmsadc -> lvm
# ├── lvmsar -> lvm
# ├── lvreduce -> lvm
# ├── lvremove -> lvm
# ├── lvrename -> lvm
# ├── lvresize -> lvm
# ├── lvs -> lvm
# ├── lvscan -> lvm
# ├── make-ssl-cert
# ├── mariadbd
# ├── mke2fs
# ├── mkfs
# ├── mkfs.bfs
# ├── mkfs.cramfs
# ├── mkfs.ext2 -> mke2fs
# ├── mkfs.ext3 -> mke2fs
# ├── mkfs.ext4 -> mke2fs
# ├── mkfs.minix
# ├── mkhomedir_helper
# ├── mkinitramfs
# ├── mklost+found
# ├── mkswap
# ├── modinfo -> /bin/kmod
# ├── modprobe -> /bin/kmod
# ├── mysqld -> mariadbd
# ├── newusers
# ├── nft
# ├── nologin
# ├── ownership
# ├── pam-auth-update
# ├── pam_getenv
# ├── pam_timestamp_check
# ├── phpdismod -> phpenmod
# ├── phpenmod
# ├── phpquery
# ├── pivot_root
# ├── poweroff -> /bin/systemctl
# ├── powertop
# ├── pvchange -> lvm
# ├── pvck -> lvm
# ├── pvcreate -> lvm
# ├── pvdisplay -> lvm
# ├── pvmove -> lvm
# ├── pvremove -> lvm
# ├── pvresize -> lvm
# ├── pvs -> lvm
# ├── pvscan -> lvm
# ├── pwck
# ├── pwconv
# ├── pwunconv
# ├── raw
# ├── readprofile
# ├── reboot -> /bin/systemctl
# ├── remove-default-ispell
# ├── remove-default-wordlist
# ├── remove-shell
# ├── resize2fs
# ├── rmmod -> /bin/kmod
# ├── rmt -> /etc/alternatives/rmt
# ├── rmt-tar
# ├── rsyslogd
# ├── rtacct
# ├── rtcwake
# ├── rtmon
# ├── runlevel -> /bin/systemctl
# ├── runuser
# ├── select-default-ispell
# ├── select-default-wordlist
# ├── service
# ├── setcap
# ├── setvesablank
# ├── sfdisk
# ├── shadowconfig
# ├── shutdown -> /bin/systemctl
# ├── split-logfile
# ├── start-stop-daemon
# ├── sudo_logsrvd
# ├── sudo_sendlog
# ├── sulogin
# ├── swaplabel
# ├── swapoff
# ├── swapon
# ├── switch_root
# ├── sysctl
# ├── tarcat
# ├── tc
# ├── tcptraceroute -> /etc/alternatives/tcptraceroute
# ├── tcptraceroute.db
# ├── telinit -> /bin/systemctl
# ├── tipc
# ├── traceroute -> /etc/alternatives/traceroute.sbin
# ├── tune2fs
# ├── tzconfig
# ├── unix_chkpwd
# ├── unix_update
# ├── update-ca-certificates
# ├── update-default-aspell -> update-dictcommon-aspell
# ├── update-default-ispell
# ├── update-default-wordlist
# ├── update-dictcommon-aspell
# ├── update-dictcommon-hunspell
# ├── update-grub
# ├── update-grub2 -> update-grub
# ├── update-initramfs
# ├── update-locale
# ├── update-mime
# ├── update-passwd
# ├── update-pciids
# ├── update-rc.d
# ├── upgrade-from-grub-legacy
# ├── useradd
# ├── userdel
# ├── usermod
# ├── validlocale
# ├── vcstime
# ├── vgcfgbackup -> lvm
# ├── vgcfgrestore -> lvm
# ├── vgchange -> lvm
# ├── vgck -> lvm
# ├── vgconvert -> lvm
# ├── vgcreate -> lvm
# ├── vgdisplay -> lvm
# ├── vgexport -> lvm
# ├── vgextend -> lvm
# ├── vgimport -> lvm
# ├── vgimportclone -> lvm
# ├── vgmerge -> lvm
# ├── vgmknodes -> lvm
# ├── vgreduce -> lvm
# ├── vgremove -> lvm
# ├── vgrename -> lvm
# ├── vgs -> lvm
# ├── vgscan -> lvm
# ├── vgsplit -> lvm
# ├── vigr -> vipw
# ├── vipw
# ├── visudo
# ├── vpddecode
# ├── wipefs
# ├── wpa_action
# ├── wpa_cli
# ├── wpa_supplicant
# ├── zic
# └── zramctl
#
# 0 directories, 293 files

# %% [markdown]
# ### The ```/lib/``` and ```/lib64/``` directories.
#
# This directory contains the system libraries.

# %%
tree /lib/ -L 1
# Out:
# /lib/
# ├── apache2
# ├── apparmor
# ├── apt
# ├── bfd-plugins
# ├── binfmt.d
# ├── cgi-bin
# ├── compat-ld
# ├── console-setup
# ├── cpp -> /etc/alternatives/cpp
# ├── crda
# ├── dbus-1.0
# ├── discover
# ├── dpkg
# ├── emacsen-common
# ├── environment.d
# ├── file
# ├── firmware
# ├── galera
# ├── gcc
# ├── git-core
# ├── gnupg
# ├── gnupg2
# ├── gold-ld
# ├── groff
# ├── grub
# ├── grub-legacy
# ├── ifupdown
# ├── init
# ├── ispell
# ├── kernel
# ├── klibc
# ├── klibc-YUkGbOClhnaZRUUd4cUed0X2XZI.so
# ├── libdiscover.so.2 -> libdiscover.so.2.0.1
# ├── libdiscover.so.2.0.1
# ├── libgalera_smm.so
# ├── libsupp.a
# ├── linux-boot-probes
# ├── locale
# ├── lsb
# ├── man-db
# ├── mc
# ├── mime
# ├── modprobe.d
# ├── modules
# ├── modules-load.d
# ├── mysql
# ├── NetworkManager
# ├── openssh
# ├── os-prober
# ├── os-probes
# ├── os-release
# ├── pam.d
# ├── php
# ├── pm-utils
# ├── python2.7
# ├── python3
# ├── python3.9
# ├── rsyslog
# ├── sasl2
# ├── ssl
# ├── sudo
# ├── sysctl.d
# ├── systemd
# ├── sysusers.d
# ├── tasksel
# ├── tc
# ├── terminfo
# ├── tmpfiles.d
# ├── udev
# ├── valgrind
# ├── w3m
# └── x86_64-linux-gnu
#
# 65 directories, 7 files

# %%
tree /lib64/ -L 1

# %% [markdown]
# ### The ```/lib/modules/``` directory.
#
# This directory contains the *Linux* kernel module libraries.

# %%
tree /lib/modules -L 2

# %% [markdown]
# ### The ```/etc/``` directory.
#
# This is the directory that contains the directories and configuration files of the system and its components.

# %%
tree /etc -L 2

# %%
tree /etc/apache2

# %% [markdown]
# ### The ```/tmp/``` directory.
#
# It is the directory that holds temporary files for the entire system and all users.

# %%
tree -L 1 /tmp

# %% [markdown]
# ### The ```/var/``` directory.
#
# This directory contains files that are used by applications and are not owned by a regular user.

# %%
tree /var/ -L 2

# %% [markdown]
# ### The ```/var/log/``` directory.
#
# This directory contains the system logs.

# %%
tree /var/log -L 1

# %% [markdown]
# ### The ```/var/www/``` directory
#
# This is the default directory for the Apache root.

# %%
tree /var/www -L 2

# %% [markdown]
# ### The ```/usr/``` directory
#
# This directory contains access (execution) directories and files for all users.

# %%
tree /usr/ -L 1

# %% [markdown]
# ### The ```/usr/local/``` directory.
#
# It is a directory that contains resources that are not for general use by the system, but can be used by specific groups of users.

# %%
tree /usr/local/ -L 1
# Out:
# /usr/local/
# ├── bin
# ├── etc
# ├── games
# ├── include
# ├── lib
# ├── man -> share/man
# ├── sbin
# ├── share
# └── src
#
# 9 directories, 0 files

# %% [markdown]
# ### The ```/opt/``` directory.
#
# This directory is for various applications.

# %%
tree /opt/

# %% [markdown]
# ### The ```/boot/``` directory.
#
# This is the directory where the * Linux * kernel image and system boot configuration is located.

# %%
tree //boot/

# %% [markdown]
# ### Directory ```/dev/```.
#
# The directory that links to the devices detected and configured by the kernel drivers.

# %%
tree /dev -L 1
# Out:
# /dev
# ├── autofs
# ├── block
# ├── bsg
# ├── btrfs-control
# ├── bus
# ├── cdrom -> sr0
# ├── char
# ├── console
# ├── core -> /proc/kcore
# ├── cpu_dma_latency
# ├── cuse
# ├── disk
# ├── dm-0
# ├── dm-1
# ├── dri
# ├── dvd -> sr0
# ├── fb0
# ├── fd -> /proc/self/fd
# ├── full
# ├── fuse
# ├── hidraw0
# ├── hpet
# ├── hugepages
# ├── initctl -> /run/initctl
# ├── input
# ├── kmsg
# ├── log -> /run/systemd/journal/dev-log
# ├── loop-control
# ├── mapper
# ├── mem
# ├── mqueue
# ├── net
# ├── null
# ├── nvram
# ├── port
# ├── ppp
# ├── psaux
# ├── ptmx
# ├── pts
# ├── pythonista-vg
# ├── random
# ├── rfkill
# ├── rtc -> rtc0
# ├── rtc0
# ├── sda
# ├── sda1
# ├── sda2
# ├── sda5
# ├── sg0
# ├── sg1
# ├── shm
# ├── snapshot
# ├── snd
# ├── sr0
# ├── stderr -> /proc/self/fd/2
# ├── stdin -> /proc/self/fd/0
# ├── stdout -> /proc/self/fd/1
# ├── tty
# ├── tty0
# ├── tty1
# ├── tty10
# ├── tty11
# ├── tty12
# ├── tty13
# ├── tty14
# ├── tty15
# ├── tty16
# ├── tty17
# ├── tty18
# ├── tty19
# ├── tty2
# ├── tty20
# ├── tty21
# ├── tty22
# ├── tty23
# ├── tty24
# ├── tty25
# ├── tty26
# ├── tty27
# ├── tty28
# ├── tty29
# ├── tty3
# ├── tty30
# ├── tty31
# ├── tty32
# ├── tty33
# ├── tty34
# ├── tty35
# ├── tty36
# ├── tty37
# ├── tty38
# ├── tty39
# ├── tty4
# ├── tty40
# ├── tty41
# ├── tty42
# ├── tty43
# ├── tty44
# ├── tty45
# ├── tty46
# ├── tty47
# ├── tty48
# ├── tty49
# ├── tty5
# ├── tty50
# ├── tty51
# ├── tty52
# ├── tty53
# ├── tty54
# ├── tty55
# ├── tty56
# ├── tty57
# ├── tty58
# ├── tty59
# ├── tty6
# ├── tty60
# ├── tty61
# ├── tty62
# ├── tty63
# ├── tty7
# ├── tty8
# ├── tty9
# ├── ttyS0
# ├── ttyS1
# ├── ttyS2
# ├── ttyS3
# ├── uhid
# ├── uinput
# ├── urandom
# ├── vboxguest
# ├── vboxuser
# ├── vcs
# ├── vcs1
# ├── vcs2
# ├── vcs3
# ├── vcs4
# ├── vcs5
# ├── vcs6
# ├── vcsa
# ├── vcsa1
# ├── vcsa2
# ├── vcsa3
# ├── vcsa4
# ├── vcsa5
# ├── vcsa6
# ├── vcsu
# ├── vcsu1
# ├── vcsu2
# ├── vcsu3
# ├── vcsu4
# ├── vcsu5
# ├── vcsu6
# ├── vfio
# ├── vga_arbiter
# ├── vhci
# ├── vhost-net
# ├── vhost-vsock
# └── zero
#
# 17 directories, 141 files

# %% [markdown]
# ### The ```/proc/``` directory.
#
# This is the directory that maps the system processes.

# %%
tree /proc/ -L 1
# Out:
# /proc/
# ├── 1
# ├── 10
# ├── 11
# ├── 112
# ├── 113
# ├── 114
# ├── 115
# ├── 116
# ├── 117
# ├── 118
# ├── 12
# ├── 127
# ├── 129
# ├── 13
# ├── 14
# ├── 16
# ├── 168
# ├── 169
# ├── 18
# ├── 19
# ├── 2
# ├── 20
# ├── 207
# ├── 21
# ├── 22
# ├── 23
# ├── 230
# ├── 24
# ├── 25
# ├── 26
# ├── 264
# ├── 284
# ├── 287
# ├── 289
# ├── 291
# ├── 293
# ├── 295
# ├── 297
# ├── 299
# ├── 3
# ├── 301
# ├── 303
# ├── 380
# ├── 388
# ├── 399
# ├── 4
# ├── 400
# ├── 403
# ├── 410
# ├── 411
# ├── 414
# ├── 432
# ├── 439
# ├── 44
# ├── 45
# ├── 46
# ├── 47
# ├── 476
# ├── 48
# ├── 49
# ├── 50
# ├── 5063
# ├── 51
# ├── 52
# ├── 549
# ├── 584
# ├── 6
# ├── 62
# ├── 6311
# ├── 6312
# ├── 6313
# ├── 6314
# ├── 6315
# ├── 6417
# ├── 6431
# ├── 65
# ├── 6550
# ├── 6551
# ├── 6552
# ├── 6596
# ├── 66
# ├── 6648
# ├── 6704
# ├── 6743
# ├── 6755
# ├── 6775
# ├── 8
# ├── 9
# ├── acpi
# ├── asound
# ├── buddyinfo
# ├── bus
# ├── cgroups
# ├── cmdline
# ├── consoles
# ├── cpuinfo
# ├── crypto
# ├── devices
# ├── diskstats
# ├── dma
# ├── driver
# ├── dynamic_debug
# ├── execdomains
# ├── fb
# ├── filesystems
# ├── fs
# ├── interrupts
# ├── iomem
# ├── ioports
# ├── irq
# ├── kallsyms
# ├── kcore
# ├── keys
# ├── key-users
# ├── kmsg
# ├── kpagecgroup
# ├── kpagecount
# ├── kpageflags
# ├── loadavg
# ├── locks
# ├── meminfo
# ├── misc
# ├── modules
# ├── mounts -> self/mounts
# ├── mtrr
# ├── net -> self/net
# ├── pagetypeinfo
# ├── partitions
# ├── pressure
# ├── sched_debug
# ├── schedstat
# ├── self -> 6775
# ├── slabinfo
# ├── softirqs
# ├── stat
# ├── swaps
# ├── sys
# ├── sysrq-trigger
# ├── sysvipc
# ├── thread-self -> 6775/task/6775
# ├── timer_list
# ├── tty
# ├── uptime
# ├── version
# ├── vmallocinfo
# ├── vmstat
# └── zoneinfo
#
# 102 directories, 45 files

# %% [markdown]
# ### The ```/sys/``` directory.
#
# This is the directory used by the kernel libraries.

# %%
tree /sys/ -L 1
# Out:
# /sys/
# ├── block
# ├── bus
# ├── class
# ├── dev
# ├── devices
# ├── firmware
# ├── fs
# ├── hypervisor
# ├── kernel
# ├── module
# └── power
#
# 11 directories, 0 files

# %% [markdown]
# ### The ```/run/``` directory.
#
# It is the directory that contains execution files of certain services and daemons.

# %%
tree /run/ -L 1
# Out:
# /run/
# ├── agetty.reload
# ├── apache2
# ├── console-setup
# ├── credentials
# ├── crond.pid
# ├── crond.reboot
# ├── dbus
# ├── dhclient.enp0s3.pid
# ├── dmeventd-client
# ├── dmeventd-server
# ├── fsck
# ├── initctl
# ├── initramfs
# ├── lock
# ├── log
# ├── lvm
# ├── mount
# ├── mysqld
# ├── network
# ├── sendsigs.omit.d
# ├── shm -> /dev/shm
# ├── sudo
# ├── systemd
# ├── tmpfiles.d
# ├── udev
# ├── user
# └── utmp
#
# 19 directories, 8 files

# %% [markdown]
# ### The ```/media/``` and ```/mnt/``` directories.
#
# These are the directories in which the various file systems are mounted.

# %%
tree /mnt/ -L 2
# Out:
# /mnt/
#
# 0 directories, 0 files

# %%
tree /media/ -L 2
# Out:
# /media/
# ├── cdrom -> cdrom0
# └── cdrom0
#
# 2 directories, 0 files

# %% [markdown]
# ## The *PATH* environment variable.
#
# This variable contains the current user's command search paths.

# %%
echo $PATH

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Creative Commons License" style=" border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />This work is licensed under a <a rel="license " href="http://creativecommons.org/licenses/by/4.0/">Creative Commons Attribution 4.0 International License</a>.</p>
# <p style="text-align: center">© Jose Luis Chiquete Valdivieso. 2020.</p>
